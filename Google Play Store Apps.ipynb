# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load datasets
df = pd.read_csv("googleplaystore.csv")

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
reviews_df = pd.read_csv("googleplaystore_user_reviews.csv")

# %%
reviews_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
# Check the information in the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#Check the shape of the data
df.shape
# Out:
# (10841, 13)

# %%
#Look for the number of unique Apps
df['App'].nunique()
# Out:
# 9660

# %%
#Checking unique categories in the data
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
#Total number of unique categories
df['Category'].nunique()
# Out:
# 34

# %%
# The gradation of installations in the dataframe
df.Installs.unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
# The gradation of installations in the dataframe
df.Installs.unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
# Looking unique ratings in the dataframe
df['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
#Checking number of unique values for the rating
df['Rating'].nunique()
# Out:
# 40

# %%
# Viewing the content rating; who is permitted to download these apps
df["Content Rating"].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated', nan], dtype=object)

# %% [markdown]
# Data Cleaning

# %%
df.duplicated().sum()
# Out:
# 483

# %%
#Dropping duplicated rows
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#Now check new data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10358 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10358 non-null  object
#  1   Category        10358 non-null  object
#  2   Rating          8893 non-null   float64
#  3   Reviews         10358 non-null  object
#  4   Size            10358 non-null  object
#  5   Installs        10358 non-null  object
#  6   Type            10357 non-null  object
#  7   Price           10358 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10358 non-null  object
#  10  Last Updated    10358 non-null  object
#  11  Current Ver     10350 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#Checking each column in the data for null values
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1465
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df['Rating'].fillna(df['Rating'].mean(), inplace=True)
# Out:
# C:\Users\Lalit Karki\AppData\Local\Temp\ipykernel_8244\1501272357.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Rating'].fillna(df['Rating'].mean(), inplace=True)

# %%
df.dropna(subset=["Type","Content Rating","Current Ver","Android Ver"],inplace=True)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
#Again check for the shape of new formed data frame
df.shape
# Out:
# (10346, 13)

# %%
df.App.nunique()
# Out:
# 9648

# %%
len(df['App'])
# Out:
# 10346

# %% [markdown]
# Exploring the Data

# %%
# Convert columns to appropriate data types
df['Reviews'] = df['Reviews'].astype(int)

# %%
df['Installs'] = df['Installs'].str.replace(',','').str.replace('+', '').astype(int)

# %%
df["Installs"] = pd.to_numeric(df["Installs"])

# %%
df['Price'] = df['Price'].str.replace('$', '').astype(float)

# %%
#Checking unique categories in the Type of the Apps
df["Type"].value_counts()
# Out:
# Type
# Free    9584
# Paid     762
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#              Rating       Reviews      Installs         Price
# count  10346.000000  1.034600e+04  1.034600e+04  10346.000000
# mean       4.188182  4.063338e+05  1.417266e+07      1.031561
# std        0.484161  2.698179e+06  8.028090e+07     16.287252
# min        1.000000  0.000000e+00  0.000000e+00      0.000000
# 25%        4.100000  3.200000e+01  1.000000e+03      0.000000
# 50%        4.200000  1.688500e+03  1.000000e+05      0.000000
# 75%        4.500000  4.659825e+04  1.000000e+06      0.000000
# max        5.000000  7.815831e+07  1.000000e+09    400.000000

# %%
df["Type"].value_counts().plot.bar()
plt.ylabel("Count")
plt.xlabel("Type")
plt.title("Value count for the type of app ")
plt.xticks(rotation=45)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10346 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10346 non-null  object
#  1   Category        10346 non-null  object
#  2   Rating          10346 non-null  float64
#  3   Reviews         10346 non-null  int32
#  4   Size            10346 non-null  object
#  5   Installs        10346 non-null  int32
#  6   Type            10346 non-null  object
#  7   Price           10346 non-null  float64
#  8   Content Rating  10346 non-null  object
#  9   Genres          10346 non-null  object
#  10  Last Updated    10346 non-null  object
#  11  Current Ver     10346 non-null  object
#  12  Android Ver     10346 non-null  object
# dtypes: float64(2), int32(2), object(9)
# memory usage: 1.0+ MB

# %%
# removing the "m" which is the mb for the size

df.Size= df["Size"].str.replace("M", "")
df.Size= df['Size'].str.replace("Varies with device","-1")

# %%
#Here we replace k and change the unit to Mb
df['Size']=df['Size'].apply(lambda x: str(round((float(x.rstrip('k'))/1024),1) )if x[-1]=='k' else x)

# %%
df.Size.unique()
# Out:
# array(['19', '14', '8.7', '25', '2.8', '5.6', '29', '33', '3.1', '28',
#        '12', '20', '21', '37', '5.5', '17', '39', '31', '4.2', '7.0',
#        '23', '6.0', '6.1', '4.6', '9.2', '5.2', '11', '24', '-1', '9.4',
#        '15', '10', '1.2', '26', '8.0', '7.9', '56', '57', '35', '54',
#        '0.2', '3.6', '5.7', '8.6', '2.4', '27', '2.7', '2.5', '16', '3.4',
#        '8.9', '3.9', '2.9', '38', '32', '5.4', '18', '1.1', '2.2', '4.5',
#        '9.8', '52', '9.0', '6.7', '30', '2.6', '7.1', '3.7', '22', '7.4',
#        '6.4', '3.2', '8.2', '9.9', '4.9', '9.5', '5.0', '5.9', '13', '73',
#        '6.8', '3.5', '4.0', '2.3', '7.2', '2.1', '42', '7.3', '9.1', '55',
#        '0.0', '6.5', '1.5', '7.5', '51', '41', '48', '8.5', '46', '8.3',
#        '4.3', '4.7', '3.3', '40', '7.8', '8.8', '6.6', '5.1', '61', '66',
#        '0.1', '8.4', '44', '0.7', '1.6', '6.2', '53', '1.4', '3.0', '5.8',
#        '3.8', '9.6', '45', '63', '49', '77', '4.4', '4.8', '70', '6.9',
#        '9.3', '10.0', '8.1', '36', '84', '97', '2.0', '1.9', '1.8', '5.3',
#        '47', '0.5', '76', '7.6', '59', '9.7', '78', '72', '43', '7.7',
#        '6.3', '0.3', '34', '93', '65', '79', '100', '58', '50', '68',
#        '64', '67', '60', '94', '99', '0.6', '95', '80', '1.7', '74', '62',
#        '69', '75', '98', '85', '82', '96', '87', '71', '86', '91', '81',
#        '92', '83', '88', '0.8', '0.9', '0.4', '1.3', '1.0', '4.1', '89',
#        '90'], dtype=object)

# %%
df.drop(['Genres','Last Updated','Current Ver',"Android Ver"],axis=1,inplace=True)

# %%
#Ensure that these columns are dropped.
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews Size  Installs  Type  Price Content Rating
# 0      159   19     10000  Free    0.0       Everyone
# 1      967   14    500000  Free    0.0       Everyone
# 2    87510  8.7   5000000  Free    0.0       Everyone
# 3   215644   25  50000000  Free    0.0           Teen
# 4      967  2.8    100000  Free    0.0       Everyone

# %%
# Here we find the count of rating for each possible mean rating
rating_most=df.Rating.value_counts()

# %%
df.Rating.value_counts()
# Out:
# Rating
# 4.189542    1460
# 4.400000    1031
# 4.300000    1016
# 4.500000     976
# 4.200000     887
# 4.600000     768
# 4.100000     656
# 4.000000     538
# 4.700000     484
# 3.900000     372
# 3.800000     293
# 5.000000     271
# 3.700000     231
# 4.800000     228
# 3.600000     169
# 3.500000     157
# 3.400000     127
# 3.300000     101
# 4.900000      87
# 3.000000      82
# 3.100000      69
# 3.200000      63
# 2.900000      45
# 2.800000      40
# 2.600000      24
# 2.700000      23
# 2.500000      20
# 2.300000      20
# 2.400000      19
# 1.000000      16
# 2.200000      14
# 1.900000      12
# 2.000000      12
# 1.700000       8
# 1.800000       8
# 2.100000       8
# 1.600000       4
# 1.400000       3
# 1.500000       3
# 1.200000       1
# Name: count, dtype: int64

# %%
# figure related code
fig = plt.figure()
fig.suptitle('Boxplot', fontsize=14, fontweight='bold')

ax = fig.add_subplot(111)
ax.boxplot(df['Rating'])
ax.set_title('Rating class v/s rating')
ax.set_xlabel('Rating class')
ax.set_ylabel('Rating')

plt.show()

# %%
# Count plot for rating
plt.figure(figsize=(15,10))
sns.set_theme(style="darkgrid")
plt.xticks(rotation=90)
plt.title("Rating V/s Count")
ax = sns.countplot(x="Rating", data=df)

# %%
#We look at the top five value counts  for rating 
df["Rating"].value_counts().nlargest(5).sort_values(ascending=True).plot.bar()
plt.ylabel("Count")
plt.xlabel("Rating")
plt.title("Playstore - Top 5 App Rating count")
plt.xticks(rotation=45)
plt.show()

# %%
# we make different classes/dataframes for the app rating
app_rating1=df[df['Rating'] >= 4]
app_rating2=df[(df['Rating'] < 4) & (df['Rating'] > 3 )]
app_rating3= df[df['Rating'] <=3]

# %%
#Checking the shape of each dataframe
app_rating1.shape,app_rating2.shape,app_rating3.shape
# Out:
# ((8402, 9), (1582, 9), (362, 9))

# %%
#Here we use the hist plot for the app rating
app_rating= df["Rating"]
num_bins=7
plt.hist(app_rating, num_bins, facecolor="green", alpha = 1)
plt.title('Playstore App Rating')
plt.xlabel(" Rating")
plt.ylabel("Number of Apps")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Here we try to find the apps with rating 5
df1=df[df['Rating']==5]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 271 entries, 329 to 10837
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             271 non-null    object
#  1   Category        271 non-null    object
#  2   Rating          271 non-null    float64
#  3   Reviews         271 non-null    int32
#  4   Size            271 non-null    object
#  5   Installs        271 non-null    int32
#  6   Type            271 non-null    object
#  7   Price           271 non-null    float64
#  8   Content Rating  271 non-null    object
# dtypes: float64(2), int32(2), object(5)
# memory usage: 19.1+ KB

# %%
df1=df1.sort_values(by=['Installs','Reviews'], ascending=False)
df1
# Out:
#                                                     App   Category  Rating  \
# 9511                           Ek Bander Ne Kholi Dukan     FAMILY     5.0
# 8058                                         Oración CX  LIFESTYLE     5.0
# 8260   Superheroes, Marvel, DC, Comics, TV, Movies News     COMICS     5.0
# 7514            CL Keyboard - Myanmar Keyboard (No Ads)      TOOLS     5.0
# 10357                                        Ríos de Fe  LIFESTYLE     5.0
# ...                                                 ...        ...     ...
# 2459    Anatomy & Physiology Vocabulary Exam Review App    MEDICAL     5.0
# 9218                                EB Cash Collections   BUSINESS     5.0
# 2454                                KBA-EZ Health Guide    MEDICAL     5.0
# 5917                                           Ra Ga Ba       GAME     5.0
# 10697                                           Mu.F.O.       GAME     5.0
#
#        Reviews Size  Installs  Type  Price Content Rating
# 9511        10  3.0     10000  Free   0.00       Everyone
# 8058       103  3.8      5000  Free   0.00       Everyone
# 8260        34   12      5000  Free   0.00       Everyone
# 7514        24  3.2      5000  Free   0.00       Everyone
# 10357      141   15      1000  Free   0.00       Everyone
# ...        ...  ...       ...   ...    ...            ...
# 2459         1  4.6         5  Free   0.00       Everyone
# 9218         1  4.3         5  Free   0.00       Everyone
# 2454         4   25         1  Free   0.00       Everyone
# 5917         2   20         1  Paid   1.49       Everyone
# 10697        2   16         1  Paid   0.99       Everyone
#
# [271 rows x 9 columns]

# %%
#Value count of each category for the apps with rating 5
df1.Category.value_counts(ascending=False)
# Out:
# Category
# FAMILY                 67
# LIFESTYLE              29
# MEDICAL                25
# BUSINESS               18
# TOOLS                  17
# GAME                   12
# HEALTH_AND_FITNESS     12
# PERSONALIZATION        10
# SOCIAL                  8
# PRODUCTIVITY            8
# FINANCE                 8
# NEWS_AND_MAGAZINES      7
# BOOKS_AND_REFERENCE     6
# SHOPPING                6
# DATING                  6
# EVENTS                  6
# PHOTOGRAPHY             6
# COMMUNICATION           5
# SPORTS                  4
# TRAVEL_AND_LOCAL        3
# LIBRARIES_AND_DEMO      2
# COMICS                  2
# FOOD_AND_DRINK          2
# ART_AND_DESIGN          1
# PARENTING               1
# Name: count, dtype: int64

# %%
#Top five categories with respect to value count of app (rating=5)
df1.Category.value_counts(ascending=False).nlargest(5).sort_values(ascending=False).plot.bar()
plt.ylabel("Number of Apps")
plt.xlabel("Category")
plt.title("Playstore - Category counts")
plt.show()

# %%
#We read the top five categories in the apps
df["Category"].value_counts().nlargest(5).sort_values(ascending=False)
# Out:
# Category
# FAMILY      1939
# GAME        1121
# TOOLS        841
# BUSINESS     427
# MEDICAL      408
# Name: count, dtype: int64

# %%
#df.Category.value_counts()
plt.figure(figsize=(10,7))
sns.set_theme(style="darkgrid")
plt.xticks(rotation=90)
plt.title("Category V/s Count")
ax = sns.countplot(x="Category", data=df)

# %%
# Getting the measures of central tendency for all the installation grouped by "Category"

df.groupby("Category").Installs.agg(["min", "mean", "median", "max"])
# Out:
#                        min          mean     median         max
# Category
# ART_AND_DESIGN           0  1.942705e+06   100000.0    50000000
# AUTO_AND_VEHICLES        1  6.250613e+05   100000.0    10000000
# BEAUTY                  50  5.131519e+05    50000.0    10000000
# BOOKS_AND_REFERENCE      1  8.368858e+06    10000.0  1000000000
# BUSINESS                 0  2.022634e+06     1000.0   100000000
# COMICS                  50  9.347692e+05   100000.0    10000000
# COMMUNICATION            1  6.598983e+07  1000000.0  1000000000
# DATING                   1  1.053756e+06   100000.0    10000000
# EDUCATION             1000  4.107323e+06  1000000.0   100000000
# ENTERTAINMENT        10000  2.212306e+07  5000000.0  1000000000
# EVENTS                   1  2.495806e+05     1000.0     5000000
# FAMILY                   0  5.178769e+06   100000.0  1000000000
# FINANCE                  0  2.139858e+06    10000.0   100000000
# FOOD_AND_DRINK           1  2.079829e+06   500000.0    10000000
# GAME                     1  2.813918e+07  1000000.0  1000000000
# HEALTH_AND_FITNESS       1  4.447786e+06   500000.0   500000000
# HOUSE_AND_HOME           1  1.565156e+06   500000.0    10000000
# LIBRARIES_AND_DEMO      10  7.380465e+05    10000.0    10000000
# LIFESTYLE                0  1.433843e+06    10000.0   100000000
# MAPS_AND_NAVIGATION     10  5.286729e+06   100000.0   100000000
# MEDICAL                  0  1.034416e+05     1000.0     5000000
# NEWS_AND_MAGAZINES       0  2.042886e+07    50000.0  1000000000
# PARENTING               10  5.253518e+05   100000.0    10000000
# PERSONALIZATION          0  5.374310e+06    10000.0   100000000
# PHOTOGRAPHY              5  3.019021e+07  3000000.0  1000000000
# PRODUCTIVITY             0  3.062185e+07   100000.0  1000000000
# SHOPPING                 5  1.148816e+07  1000000.0   100000000
# SOCIAL                   0  4.469239e+07  1000000.0  1000000000
# SPORTS                   1  4.354913e+06   100000.0   100000000
# TOOLS                    1  1.361745e+07    50000.0  1000000000
# TRAVEL_AND_LOCAL         0  2.684341e+07   500000.0  1000000000
# VIDEO_PLAYERS           10  3.555430e+07  1000000.0  1000000000
# WEATHER                 10  5.196348e+06  1000000.0    50000000

# %%
df.sort_values(by="Installs", ascending= False).head()
# Out:
#                             App            Category  Rating   Reviews Size  \
# 336          WhatsApp Messenger       COMMUNICATION     4.4  69119316   -1
# 2554                    Google+              SOCIAL     4.2   4831125   -1
# 3127         Google Street View    TRAVEL_AND_LOCAL     4.2   2129689   -1
# 3816                Google News  NEWS_AND_MAGAZINES     3.9    877643   13
# 3223  Maps - Navigate & Explore    TRAVEL_AND_LOCAL     4.3   9235373   -1
#
#         Installs  Type  Price Content Rating
# 336   1000000000  Free    0.0       Everyone
# 2554  1000000000  Free    0.0           Teen
# 3127  1000000000  Free    0.0       Everyone
# 3816  1000000000  Free    0.0           Teen
# 3223  1000000000  Free    0.0       Everyone

# %%
#Here we make dataframe for top most installed apps
top_installed_apps=df.sort_values(by="Installs", ascending= False)

# %%
#We read first 5 rows of this dataframe
top_installed_apps.head()
# Out:
#                             App            Category  Rating   Reviews Size  \
# 336          WhatsApp Messenger       COMMUNICATION     4.4  69119316   -1
# 2554                    Google+              SOCIAL     4.2   4831125   -1
# 3127         Google Street View    TRAVEL_AND_LOCAL     4.2   2129689   -1
# 3816                Google News  NEWS_AND_MAGAZINES     3.9    877643   13
# 3223  Maps - Navigate & Explore    TRAVEL_AND_LOCAL     4.3   9235373   -1
#
#         Installs  Type  Price Content Rating
# 336   1000000000  Free    0.0       Everyone
# 2554  1000000000  Free    0.0           Teen
# 3127  1000000000  Free    0.0       Everyone
# 3816  1000000000  Free    0.0           Teen
# 3223  1000000000  Free    0.0       Everyone

# %%
len(df[df["Installs"]>= 1000000000])
# Out:
# 49

# %%
top_installed_and_rated_apps = df.sort_values(by=["Installs", "Rating"], ascending=False)

# %%
top_installed_and_rated_apps.head()
# Out:
#                  App Category  Rating   Reviews Size    Installs  Type  Price  \
# 1654  Subway Surfers     GAME     4.5  27722264   76  1000000000  Free    0.0
# 1700  Subway Surfers     GAME     4.5  27723193   76  1000000000  Free    0.0
# 1750  Subway Surfers     GAME     4.5  27724094   76  1000000000  Free    0.0
# 1872  Subway Surfers     GAME     4.5  27725352   76  1000000000  Free    0.0
# 2545       Instagram   SOCIAL     4.5  66577313   -1  1000000000  Free    0.0
#
#      Content Rating
# 1654   Everyone 10+
# 1700   Everyone 10+
# 1750   Everyone 10+
# 1872   Everyone 10+
# 2545           Teen

# %%
#Now, we make dataframe for most installed and reviewed apps
top_installed_and_reviewed_apps = df.sort_values(by=["Installs", "Reviews"], ascending=False)
top_installed_and_reviewed_apps.head()
# Out:
#                      App       Category  Rating   Reviews Size    Installs  \
# 2544            Facebook         SOCIAL     4.1  78158306   -1  1000000000
# 3943            Facebook         SOCIAL     4.1  78128208   -1  1000000000
# 336   WhatsApp Messenger  COMMUNICATION     4.4  69119316   -1  1000000000
# 3904  WhatsApp Messenger  COMMUNICATION     4.4  69109672   -1  1000000000
# 2604           Instagram         SOCIAL     4.5  66577446   -1  1000000000
#
#       Type  Price Content Rating
# 2544  Free    0.0           Teen
# 3943  Free    0.0           Teen
# 336   Free    0.0       Everyone
# 3904  Free    0.0       Everyone
# 2604  Free    0.0           Teen

# %%
#Making another dataframe having 10 rows of the dataframetop_installed_and_rated_apps
top_10_installed_and_rated_apps= top_installed_and_rated_apps.head(10)

# %%
#finding top 10 installed and rated app 
top_10_installed_and_rated_apps.Category.sort_values(ascending=False)
# Out:
# 2545         SOCIAL
# 2604         SOCIAL
# 2808    PHOTOGRAPHY
# 2853    PHOTOGRAPHY
# 2884    PHOTOGRAPHY
# 1654           GAME
# 1700           GAME
# 1750           GAME
# 1872           GAME
# 3896           GAME
# Name: Category, dtype: object

# %%
# There are totally 8190 apps
df["App"].nunique()
# Out:
# 9648

# %%
#Top 10 installed and rated apps in accordance with content rating
top_10_installed_and_rated_apps["Content Rating"].sort_values(ascending=False)
# Out:
# 2545            Teen
# 2604            Teen
# 1654    Everyone 10+
# 1700    Everyone 10+
# 1750    Everyone 10+
# 1872    Everyone 10+
# 3896    Everyone 10+
# 2808        Everyone
# 2853        Everyone
# 2884        Everyone
# Name: Content Rating, dtype: object

# %%
#Basic pie chart to view distribution of apps across various categories
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(aspect="equal"))
number_of_apps = df["Content Rating"].value_counts()
labels = number_of_apps.index
sizes = number_of_apps.values
ax.pie(sizes,labeldistance=2,autopct='%1.1f%%')
ax.legend(labels=labels,loc="right",bbox_to_anchor=(0.9, 0, 0.5, 1))

# %%
# In this and in the next 2 commands, i will try to see if there is any correlation between installations, Rating and Reviews

top_10_installed_and_rated_apps
# Out:
#                  App     Category  Rating   Reviews Size    Installs  Type  \
# 1654  Subway Surfers         GAME     4.5  27722264   76  1000000000  Free
# 1700  Subway Surfers         GAME     4.5  27723193   76  1000000000  Free
# 1750  Subway Surfers         GAME     4.5  27724094   76  1000000000  Free
# 1872  Subway Surfers         GAME     4.5  27725352   76  1000000000  Free
# 2545       Instagram       SOCIAL     4.5  66577313   -1  1000000000  Free
# 2604       Instagram       SOCIAL     4.5  66577446   -1  1000000000  Free
# 2808   Google Photos  PHOTOGRAPHY     4.5  10858556   -1  1000000000  Free
# 2853   Google Photos  PHOTOGRAPHY     4.5  10858538   -1  1000000000  Free
# 2884   Google Photos  PHOTOGRAPHY     4.5  10859051   -1  1000000000  Free
# 3896  Subway Surfers         GAME     4.5  27711703   76  1000000000  Free
#
#       Price Content Rating
# 1654    0.0   Everyone 10+
# 1700    0.0   Everyone 10+
# 1750    0.0   Everyone 10+
# 1872    0.0   Everyone 10+
# 2545    0.0           Teen
# 2604    0.0           Teen
# 2808    0.0       Everyone
# 2853    0.0       Everyone
# 2884    0.0       Everyone
# 3896    0.0   Everyone 10+

# %%
df.sort_values(by="Rating", ascending= False).head()
# Out:
#                                      App       Category  Rating  Reviews Size  \
# 6727                           BS-Mobile  COMMUNICATION     5.0        1  0.7
# 6396                        Bk Usha behn      LIFESTYLE     5.0       10  3.0
# 5685  Jobs in Canada - Emplois au Canada       BUSINESS     5.0        2   14
# 7506                             CL REPL          TOOLS     5.0       47   17
# 9498      EK Bailey Preaching Conference         EVENTS     5.0        3   30
#
#       Installs  Type  Price Content Rating
# 6727        50  Free    0.0       Everyone
# 6396      1000  Free    0.0       Everyone
# 5685      1000  Free    0.0           Teen
# 7506      1000  Free    0.0       Everyone
# 9498       500  Free    0.0       Everyone

# %%
#Here we read top  apps sorted by reviews
df.sort_values(by="Reviews", ascending= False).head()
# Out:
#                      App       Category  Rating   Reviews Size    Installs  \
# 2544            Facebook         SOCIAL     4.1  78158306   -1  1000000000
# 3943            Facebook         SOCIAL     4.1  78128208   -1  1000000000
# 336   WhatsApp Messenger  COMMUNICATION     4.4  69119316   -1  1000000000
# 3904  WhatsApp Messenger  COMMUNICATION     4.4  69109672   -1  1000000000
# 2604           Instagram         SOCIAL     4.5  66577446   -1  1000000000
#
#       Type  Price Content Rating
# 2544  Free    0.0           Teen
# 3943  Free    0.0           Teen
# 336   Free    0.0       Everyone
# 3904  Free    0.0       Everyone
# 2604  Free    0.0           Teen

# %%
top_10_installed_and_rated_apps
# Out:
#                  App     Category  Rating   Reviews Size    Installs  Type  \
# 1654  Subway Surfers         GAME     4.5  27722264   76  1000000000  Free
# 1700  Subway Surfers         GAME     4.5  27723193   76  1000000000  Free
# 1750  Subway Surfers         GAME     4.5  27724094   76  1000000000  Free
# 1872  Subway Surfers         GAME     4.5  27725352   76  1000000000  Free
# 2545       Instagram       SOCIAL     4.5  66577313   -1  1000000000  Free
# 2604       Instagram       SOCIAL     4.5  66577446   -1  1000000000  Free
# 2808   Google Photos  PHOTOGRAPHY     4.5  10858556   -1  1000000000  Free
# 2853   Google Photos  PHOTOGRAPHY     4.5  10858538   -1  1000000000  Free
# 2884   Google Photos  PHOTOGRAPHY     4.5  10859051   -1  1000000000  Free
# 3896  Subway Surfers         GAME     4.5  27711703   76  1000000000  Free
#
#       Price Content Rating
# 1654    0.0   Everyone 10+
# 1700    0.0   Everyone 10+
# 1750    0.0   Everyone 10+
# 1872    0.0   Everyone 10+
# 2545    0.0           Teen
# 2604    0.0           Teen
# 2808    0.0       Everyone
# 2853    0.0       Everyone
# 2884    0.0       Everyone
# 3896    0.0   Everyone 10+

# %%
# We are looking for the top 10 apps that are installed and rated.
app4= top_10_installed_and_rated_apps
top_apps=app4.groupby(["Installs", "App"]).size().unstack()
top_apps.plot(kind="bar",stacked=True)
plt.title('top 10 installed and rated apps')
ax=plt.gca()
plt.show()

# %%
# Prices of the apps
df["Price"].value_counts().sort_values(ascending=False).head(10)
# Out:
# Price
# 0.00    9584
# 0.99     144
# 2.99     125
# 1.99      73
# 4.99      70
# 3.99      60
# 1.49      45
# 5.99      27
# 2.49      25
# 9.99      19
# Name: count, dtype: int64

# %%
#Let's look at why family even though has lot of apps does not have the highest number of installs.
paid_apps = df[df["Price"] != 0.0]

# %%
paid_family_apps = paid_apps[paid_apps["Category"]=="FAMILY"]
paid_family_apps.count()
# Out:
# App               186
# Category          186
# Rating            186
# Reviews           186
# Size              186
# Installs          186
# Type              186
# Price             186
# Content Rating    186
# dtype: int64

# %%
paid_communications_apps = paid_apps[paid_apps["Category"]=="COMMUNICATION"]
paid_communications_apps.count()
# Out:
# App               27
# Category          27
# Rating            27
# Reviews           27
# Size              27
# Installs          27
# Type              27
# Price             27
# Content Rating    27
# dtype: int64

# %%
#Let's visualize this in the form of a simple bar graph
plt.figure(figsize=(10,8))
sns.barplot(x="Category", y="Price", data=paid_apps,
            label="Total Paid Apps in Each Category")
plt.title("Paid apps")
plt.xticks(rotation=90)
plt.show()

# %%
#Here we look for the top five prices and the number of apps 
df["Price"].value_counts().nlargest(5).sort_values(ascending=False)
# Out:
# Price
# 0.00    9584
# 0.99     144
# 2.99     125
# 1.99      73
# 4.99      70
# Name: count, dtype: int64

# %%
#Now we visualize it by using bar plot
#This plot shows that data has more than 90% apps that are free 
df["Price"].value_counts().nlargest(5).sort_values(ascending=False).plot.bar()
plt.ylabel("Number of Apps")
plt.xlabel("Prices in Dollars")
plt.title("Playstore - Prices")
plt.show()

# %%
#Basic pie chart to view distribution of apps across various categories
fig, ax = plt.subplots(figsize=(9, 9), subplot_kw=dict(aspect="equal"))
number_of_apps = df["Category"].value_counts()
labels = number_of_apps.index
sizes = number_of_apps.values
ax.pie(sizes,labeldistance=2,autopct='%1.1f%%')
ax.legend(labels=labels,loc="right",bbox_to_anchor=(0.9, 0, 0.5, 1))
ax.axis("equal")
# Out:
# (-1.099999999951876,
#  1.0999999999977084,
#  -1.099999998628117,
#  1.0999999712253663)

# %%
# Here we see the category and count of top 100 installed apps
top_installed_and_rated_apps["Category"].head(100).value_counts()
# Out:
# Category
# COMMUNICATION          24
# GAME                   19
# TOOLS                  10
# SOCIAL                  9
# PRODUCTIVITY            9
# NEWS_AND_MAGAZINES      7
# VIDEO_PLAYERS           6
# TRAVEL_AND_LOCAL        5
# PHOTOGRAPHY             4
# FAMILY                  4
# ENTERTAINMENT           1
# BOOKS_AND_REFERENCE     1
# HEALTH_AND_FITNESS      1
# Name: count, dtype: int64

# %%
#Here We use the barplot to see the value counts of category in the top installed and rated apps
top_installed_and_rated_apps["Category"].head(100).value_counts().nlargest(5).sort_values(ascending=False).plot.bar()
plt.ylabel("Number of Apps")
plt.xlabel("Category")
plt.title("Playstore - Category counts_Most rated and installed apps")
plt.show()

# %%
# Relationship betweeen: Classes and number of Installations

df["Installs"].value_counts().plot.bar()
plt.ylabel("Number of Installations")
plt.xlabel("Classes of Installations")
plt.title("Playstore - Grading in Number of Installations")
plt.show()

# %%
# Top 5 Gradings in the number of installations

df["Installs"].value_counts().nlargest(5)
# Out:
# Installs
# 1000000     1487
# 10000000    1132
# 100000      1129
# 10000       1031
# 1000         888
# Name: count, dtype: int64

# %%
#we look at the classes of content rating and their value counts
df["Content Rating"].value_counts()
# Out:
# Content Rating
# Everyone           8372
# Teen               1146
# Mature 17+          447
# Everyone 10+        376
# Adults only 18+       3
# Unrated               2
# Name: count, dtype: int64

# %%
#Plot for content rating
#This plot shows that more than 7000 apps allows the content reviews to everyone
df["Content Rating"].value_counts().sort_values(ascending=False).plot.bar()
plt.ylabel("Number of Apps")
plt.xlabel("Content Rating")
plt.title("Playstore - Content Rating")
plt.show()

# %%
#The top 100 installed and rated apps corresponding to their content rating classes and the value count
top_installed_and_rated_apps["Content Rating"].head(100).value_counts()
# Out:
# Content Rating
# Everyone        71
# Teen            20
# Everyone 10+     7
# Mature 17+       2
# Name: count, dtype: int64

# %%
#we use the barplot to visualize above information
top_installed_and_rated_apps["Content Rating"].head(100).value_counts().sort_values(ascending=False).plot.bar()
plt.ylabel("Number of Apps")
plt.xlabel("Content Rating classes")
plt.title("Playstore - Content Rating for top 100 installed and rated apps")
plt.show()

# %%
#Here we look for the content rating distribution using pie chart
app1=top_installed_and_rated_apps.head(100)
app1["Content Rating"].value_counts().plot.pie()
plt.title("Content Rating - Top 100 (Main) Apps")
plt.show()

# %%
#Here we are looking for the top 100 installed and rated apps classes for the classes
top_installed_and_rated_apps.head(100).Installs.value_counts(ascending=False)
# Out:
# Installs
# 500000000     51
# 1000000000    49
# Name: count, dtype: int64

# %%
# Pie chart below gives the gradation of installation for top 100 rated and installed apps
app2= top_installed_and_rated_apps.head(100)
app2["Installs"].value_counts().plot.pie()
plt.title("Gradation of Installations - Main Top 100 Apps")
plt.show()

# %%
df1 = pd.read_csv("googleplaystore_user_reviews.csv")
df1
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# ...                            ...
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# ...                                                  ...       ...
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# 64292                                                NaN       NaN
# 64293                                                NaN       NaN
# 64294                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                    1.00                0.533333
# 1                    0.25                0.288462
# 2                     NaN                     NaN
# 3                    0.40                0.875000
# 4                    1.00                0.300000
# ...                   ...                     ...
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN
#
# [64295 rows x 5 columns]

# %%
#Read the number of unique categories in the dataset
df1.App.nunique()
# Out:
# 1074

# %%
#Read the information in the dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %%
#Dropping the rows corresponding to nan values
df1=df1.dropna()

# %%
df1.isnull().sum()
# Out:
# App                       0
# Translated_Review         0
# Sentiment                 0
# Sentiment_Polarity        0
# Sentiment_Subjectivity    0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 7735

# %%
df1.drop_duplicates(inplace=True)
# Out:
# C:\Users\Lalit Karki\AppData\Local\Temp\ipykernel_8244\528690512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop_duplicates(inplace=True)

# %%
df1.drop_duplicates(subset='App', keep='first', inplace=True)
# Out:
# C:\Users\Lalit Karki\AppData\Local\Temp\ipykernel_8244\2914515277.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop_duplicates(subset='App', keep='first', inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 865 entries, 0 to 64196
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     865 non-null    object
#  1   Translated_Review       865 non-null    object
#  2   Sentiment               865 non-null    object
#  3   Sentiment_Polarity      865 non-null    float64
#  4   Sentiment_Subjectivity  865 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 40.5+ KB

# %%
#After dropping nan value rows
df1.App.nunique()
# Out:
# 865

# %%
#Look at the statistical information of the dataframe
df1.describe()
# Out:
#        Sentiment_Polarity  Sentiment_Subjectivity
# count          865.000000              865.000000
# mean             0.168035                0.489572
# std              0.304094                0.221205
# min             -1.000000                0.000000
# 25%              0.000000                0.387500
# 50%              0.149762                0.506481
# 75%              0.333493                0.612500
# max              1.000000                1.000000

# %%
#For the column sentiment, we find the count of each sentiment in the dataset
df1.Sentiment.value_counts()
# Out:
# Sentiment
# Positive    577
# Negative    204
# Neutral      84
# Name: count, dtype: int64

# %%
#The barplot of the sentiment count shows that more than 60% of the sentiment is positive
df1["Sentiment"].value_counts().sort_values(ascending=False).plot.bar()
plt.ylabel("Sentiment Count")
plt.xlabel("Sentiment")
plt.title("User reviews")
plt.show()

# %%
#Each app has different sentiments. so we use groupbymethod for app
data=df1.groupby("App")

# %%
data

# %%
data.max()
# Out:
#                                                                                     Translated_Review  \
# App
# 10 Best Foods for You                               I like eat delicious food. That's I'm cooking ...
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                                                Great
# 11st                                                                         Horrible ID verification
# 1800 Contacts - Lens Store                          Great hassle free way order contacts. Got call...
# 1LINE – One Line with One Touch                     gets 1* there's ad every single level restart,...
# ...                                                                                               ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals  Bookings stopped showing app. Helpline useless...
# Hotspot Shield Free VPN Proxy & Wi-Fi Security        7 days free trial asking credit card. Stupid!!!
# Hotstar                                                                                       running
# Hotwire Hotel & Car Rental App                      The worthless. It allow see information would ...
# Housing-Real Estate & Property                      Incorrect listings. The agents show property d...
#
#                                                    Sentiment  \
# App
# 10 Best Foods for You                               Positive
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                    Positive
# 11st                                                Negative
# 1800 Contacts - Lens Store                          Positive
# 1LINE – One Line with One Touch                     Negative
# ...                                                      ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals  Positive
# Hotspot Shield Free VPN Proxy & Wi-Fi Security      Negative
# Hotstar                                              Neutral
# Hotwire Hotel & Car Rental App                      Negative
# Housing-Real Estate & Property                      Negative
#
#                                                     Sentiment_Polarity  \
# App
# 10 Best Foods for You                                         1.000000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                              0.800000
# 11st                                                         -1.000000
# 1800 Contacts - Lens Store                                    0.600000
# 1LINE – One Line with One Touch                              -0.157143
# ...                                                                ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals            0.291667
# Hotspot Shield Free VPN Proxy & Wi-Fi Security               -0.300000
# Hotstar                                                       0.000000
# Hotwire Hotel & Car Rental App                               -0.233333
# Housing-Real Estate & Property                               -0.025000
#
#                                                     Sentiment_Subjectivity
# App
# 10 Best Foods for You                                             0.533333
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                  0.750000
# 11st                                                              1.000000
# 1800 Contacts - Lens Store                                        0.775000
# 1LINE – One Line with One Touch                                   0.704762
# ...                                                                    ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals                0.566667
# Hotspot Shield Free VPN Proxy & Wi-Fi Security                    0.900000
# Hotstar                                                           0.000000
# Hotwire Hotel & Car Rental App                                    0.655556
# Housing-Real Estate & Property                                    0.125000
#
# [865 rows x 4 columns]

# %%
data.min()
# Out:
#                                                                                     Translated_Review  \
# App
# 10 Best Foods for You                               I like eat delicious food. That's I'm cooking ...
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                                                Great
# 11st                                                                         Horrible ID verification
# 1800 Contacts - Lens Store                          Great hassle free way order contacts. Got call...
# 1LINE – One Line with One Touch                     gets 1* there's ad every single level restart,...
# ...                                                                                               ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals  Bookings stopped showing app. Helpline useless...
# Hotspot Shield Free VPN Proxy & Wi-Fi Security        7 days free trial asking credit card. Stupid!!!
# Hotstar                                                                                       running
# Hotwire Hotel & Car Rental App                      The worthless. It allow see information would ...
# Housing-Real Estate & Property                      Incorrect listings. The agents show property d...
#
#                                                    Sentiment  \
# App
# 10 Best Foods for You                               Positive
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                    Positive
# 11st                                                Negative
# 1800 Contacts - Lens Store                          Positive
# 1LINE – One Line with One Touch                     Negative
# ...                                                      ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals  Positive
# Hotspot Shield Free VPN Proxy & Wi-Fi Security      Negative
# Hotstar                                              Neutral
# Hotwire Hotel & Car Rental App                      Negative
# Housing-Real Estate & Property                      Negative
#
#                                                     Sentiment_Polarity  \
# App
# 10 Best Foods for You                                         1.000000
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                              0.800000
# 11st                                                         -1.000000
# 1800 Contacts - Lens Store                                    0.600000
# 1LINE – One Line with One Touch                              -0.157143
# ...                                                                ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals            0.291667
# Hotspot Shield Free VPN Proxy & Wi-Fi Security               -0.300000
# Hotstar                                                       0.000000
# Hotwire Hotel & Car Rental App                               -0.233333
# Housing-Real Estate & Property                               -0.025000
#
#                                                     Sentiment_Subjectivity
# App
# 10 Best Foods for You                                             0.533333
# 104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室                                  0.750000
# 11st                                                              1.000000
# 1800 Contacts - Lens Store                                        0.775000
# 1LINE – One Line with One Touch                                   0.704762
# ...                                                                    ...
# Hotels.com: Book Hotel Rooms & Find Vacation Deals                0.566667
# Hotspot Shield Free VPN Proxy & Wi-Fi Security                    0.900000
# Hotstar                                                           0.000000
# Hotwire Hotel & Car Rental App                                    0.655556
# Housing-Real Estate & Property                                    0.125000
#
# [865 rows x 4 columns]
