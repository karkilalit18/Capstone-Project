# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
smokers=pd.read_csv("smokers.csv")
prescriptions=pd.read_csv("prescriptions.csv")
metrics=pd.read_csv("metrics.csv")
fatalities=pd.read_csv("fatalities.csv")
admissions=pd.read_csv("admissions.csv")

# %%
smokers.isnull().sum()
# Out:
# Year            0
# Method          0
# Sex            28
# 16 and Over     0
# 16-24           0
# 25-34           0
# 35-49           0
# 50-59           0
# 60 and Over     0
# dtype: int64

# %%
# Fill missing 'Sex' with mode (most frequent category)
smokers['Sex'].fillna(smokers['Sex'].mode()[0], inplace=True)
# Out:
# C:\Users\Lalit Karki\AppData\Local\Temp\ipykernel_4592\1550698879.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   smokers['Sex'].fillna(smokers['Sex'].mode()[0], inplace=True)

# %%
smokers.isnull().sum()
# Out:
# Year           0
# Method         0
# Sex            0
# 16 and Over    0
# 16-24          0
# 25-34          0
# 35-49          0
# 50-59          0
# 60 and Over    0
# dtype: int64

# %%
prescriptions.isnull().sum()
# Out:
# Year                                                           0
# All Pharmacotherapy Prescriptions                              0
# Nicotine Replacement Therapy (NRT) Prescriptions               0
# Bupropion (Zyban) Prescriptions                                0
# Varenicline (Champix) Prescriptions                            2
# Net Ingredient Cost of All Pharmacotherapies                   0
# Net Ingredient Cost of Nicotine Replacement Therapies (NRT)    0
# Net Ingredient Cost of Bupropion (Zyban)                       0
# Net Ingredient Cost of Varenicline (Champix)                   2
# dtype: int64

# %%
cols_to_fill = [
    'Varenicline (Champix) Prescriptions',
    'Net Ingredient Cost of Varenicline (Champix)']

prescriptions[cols_to_fill] = prescriptions[cols_to_fill].apply(lambda col: col.fillna(col.mean()))

# %%
prescriptions.isnull().sum()
# Out:
# Year                                                           0
# All Pharmacotherapy Prescriptions                              0
# Nicotine Replacement Therapy (NRT) Prescriptions               0
# Bupropion (Zyban) Prescriptions                                0
# Varenicline (Champix) Prescriptions                            0
# Net Ingredient Cost of All Pharmacotherapies                   0
# Net Ingredient Cost of Nicotine Replacement Therapies (NRT)    0
# Net Ingredient Cost of Bupropion (Zyban)                       0
# Net Ingredient Cost of Varenicline (Champix)                   0
# dtype: int64

# %%
metrics.isnull().sum()
# Out:
# Year                                                     0
# Tobacco Price\nIndex                                     0
# Retail Prices\nIndex                                     0
# Tobacco Price Index Relative to Retail Price Index       0
# Real Households' Disposable Income                       0
# Affordability of Tobacco Index                           0
# Household Expenditure on Tobacco                         5
# Household Expenditure Total                              5
# Expenditure on Tobacco as a Percentage of Expenditure    5
# dtype: int64

# %%
metrics.dropna(inplace=True)

# %%
metrics
# Out:
#     Year  Tobacco Price\nIndex  Retail Prices\nIndex  \
# 0   2015                1294.3                 386.7
# 1   2014                1226.0                 383.0
# 2   2013                1139.3                 374.2
# 3   2012                1057.8                 363.1
# 4   2011                 974.9                 351.9
# 5   2010                 878.3                 334.5
# 6   2009                 815.9                 319.7
# 7   2008                 784.7                 321.3
# 8   2007                 751.5                 309.1
# 9   2006                 713.7                 296.4
# 10  2005                 683.1                 287.2
# 11  2004                 654.6                 279.3
# 12  2003                 632.0                 271.2
# 13  2002                 610.4                 263.6
# 14  2001                 592.5                 259.3
# 15  2000                 562.0                 254.8
# 16  1999                 517.3                 247.4
# 17  1998                 464.1                 243.7
# 18  1997                 427.3                 235.6
# 19  1996                 398.0                 228.4
# 20  1995                 373.0                 223.1
# 21  1994                 349.6                 215.6
# 22  1993                 325.0                 210.5
# 23  1992                 299.7                 207.2
# 24  1991                 270.0                 199.7
# 25  1990                 236.1                 188.6
# 26  1989                 221.1                 172.3
# 27  1988                 214.9                 159.9
# 28  1987                 208.0                 152.4
# 29  1986                 201.6                 146.3
# 30  1985                 183.5                 141.5
#
#     Tobacco Price Index Relative to Retail Price Index  \
# 0                                               334.7
# 1                                               320.1
# 2                                               304.5
# 3                                               291.3
# 4                                               277.1
# 5                                               262.6
# 6                                               255.2
# 7                                               244.2
# 8                                               243.1
# 9                                               240.8
# 10                                              237.8
# 11                                              234.4
# 12                                              233.0
# 13                                              231.6
# 14                                              228.5
# 15                                              220.6
# 16                                              209.0
# 17                                              190.4
# 18                                              181.3
# 19                                              174.2
# 20                                              167.2
# 21                                              162.2
# 22                                              154.4
# 23                                              144.6
# 24                                              135.2
# 25                                              125.1
# 26                                              128.3
# 27                                              134.4
# 28                                              136.5
# 29                                              137.8
# 30                                              129.7
#
#     Real Households' Disposable Income  Affordability of Tobacco Index  \
# 0                                196.4                            58.7
# 1                                190.0                            59.4
# 2                                190.3                            62.5
# 3                                192.9                            66.2
# 4                                189.3                            68.3
# 5                                195.0                            74.3
# 6                                195.7                            76.7
# 7                                192.5                            78.8
# 8                                195.9                            80.6
# 9                                192.3                            79.9
# 10                               190.6                            80.1
# 11                               188.7                            80.5
# 12                               187.4                            80.4
# 13                               184.4                            79.6
# 14                               180.8                            79.1
# 15                               173.3                            78.5
# 16                               163.7                            78.3
# 17                               158.8                            83.4
# 18                               155.6                            85.8
# 19                               150.0                            86.1
# 20                               145.7                            87.1
# 21                               142.1                            87.6
# 22                               139.5                            90.3
# 23                               135.9                            93.9
# 24                               132.0                            97.6
# 25                               129.5                           103.5
# 26                               124.8                            97.2
# 27                               118.8                            88.4
# 28                               112.8                            82.6
# 29                               111.6                            81.0
# 30                               107.5                            82.9
#
#     Household Expenditure on Tobacco  Household Expenditure Total  \
# 0                            19252.0                    1152387.0
# 1                            19411.0                    1118992.0
# 2                            18683.0                    1073106.0
# 3                            18702.0                    1029378.0
# 4                            18217.0                     990828.0
# 5                            17176.0                     954781.0
# 6                            16209.0                     911665.0
# 7                            15879.0                     928265.0
# 8                            15766.0                     898478.0
# 9                            15542.0                     851456.0
# 10                           15300.0                     813580.0
# 11                           15375.0                     772164.0
# 12                           15223.0                     731780.0
# 13                           14465.0                     695912.0
# 14                           14339.0                     665058.0
# 15                           14026.0                     639405.0
# 16                           14047.0                     602922.0
# 17                           13318.0                     569829.0
# 18                           12696.0                     534755.0
# 19                           12265.0                     499354.0
# 20                           11519.0                     465225.0
# 21                           10933.0                     441911.0
# 22                           10759.0                     420673.0
# 23                           10280.0                     396519.0
# 24                            9648.0                     374468.0
# 25                            8649.0                     349982.0
# 26                            8170.0                     322967.0
# 27                            7936.0                     294521.0
# 28                            7665.0                     260425.0
# 29                            7485.0                     237015.0
# 30                            7006.0                     214449.0
#
#     Expenditure on Tobacco as a Percentage of Expenditure
# 0                                                 1.7
# 1                                                 1.7
# 2                                                 1.7
# 3                                                 1.8
# 4                                                 1.8
# 5                                                 1.8
# 6                                                 1.8
# 7                                                 1.7
# 8                                                 1.8
# 9                                                 1.8
# 10                                                1.9
# 11                                                2.0
# 12                                                2.1
# 13                                                2.1
# 14                                                2.2
# 15                                                2.2
# 16                                                2.3
# 17                                                2.3
# 18                                                2.4
# 19                                                2.5
# 20                                                2.5
# 21                                                2.5
# 22                                                2.6
# 23                                                2.6
# 24                                                2.6
# 25                                                2.5
# 26                                                2.5
# 27                                                2.7
# 28                                                2.9
# 29                                                3.2
# 30                                                3.3

# %%
fatalities.isnull().sum()
# Out:
# Year                 0
# ICD10 Code           0
# ICD10 Diagnosis      0
# Diagnosis Type       0
# Metric               0
# Sex                583
# Value                0
# dtype: int64

# %%
fatalities['Sex'].fillna(fatalities['Sex'].mode()[0], inplace=True)
# Out:
# C:\Users\Lalit Karki\AppData\Local\Temp\ipykernel_4592\667518591.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   fatalities['Sex'].fillna(fatalities['Sex'].mode()[0], inplace=True)

# %%
fatalities.isnull().sum()
# Out:
# Year               0
# ICD10 Code         0
# ICD10 Diagnosis    0
# Diagnosis Type     0
# Metric             0
# Sex                0
# Value              0
# dtype: int64

# %%
admissions.isnull().sum()
# Out:
# Year                 0
# ICD10 Code           0
# ICD10 Diagnosis      0
# Diagnosis Type       0
# Metric               0
# Sex                693
# Value                1
# dtype: int64

# %%
admissions['Sex'].fillna(admissions['Sex'].mode()[0], inplace=True)
# Out:
# C:\Users\Lalit Karki\AppData\Local\Temp\ipykernel_4592\1042853545.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   admissions['Sex'].fillna(admissions['Sex'].mode()[0], inplace=True)

# %%
admissions.dropna(subset=['Value'], inplace=True)

# %%
admissions.isnull().sum()
# Out:
# Year               0
# ICD10 Code         0
# ICD10 Diagnosis    0
# Diagnosis Type     0
# Metric             0
# Sex                0
# Value              0
# dtype: int64

# %%
smokers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Year         84 non-null     int64
#  1   Method       84 non-null     object
#  2   Sex          84 non-null     object
#  3   16 and Over  84 non-null     int64
#  4   16-24        84 non-null     int64
#  5   25-34        84 non-null     int64
#  6   35-49        84 non-null     int64
#  7   50-59        84 non-null     int64
#  8   60 and Over  84 non-null     int64
# dtypes: int64(7), object(2)
# memory usage: 6.0+ KB

# %%
prescriptions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 9 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Year                                                         11 non-null     object
#  1   All Pharmacotherapy Prescriptions                            11 non-null     int64
#  2   Nicotine Replacement Therapy (NRT) Prescriptions             11 non-null     int64
#  3   Bupropion (Zyban) Prescriptions                              11 non-null     int64
#  4   Varenicline (Champix) Prescriptions                          11 non-null     float64
#  5   Net Ingredient Cost of All Pharmacotherapies                 11 non-null     int64
#  6   Net Ingredient Cost of Nicotine Replacement Therapies (NRT)  11 non-null     int64
#  7   Net Ingredient Cost of Bupropion (Zyban)                     11 non-null     int64
#  8   Net Ingredient Cost of Varenicline (Champix)                 11 non-null     float64
# dtypes: float64(2), int64(6), object(1)
# memory usage: 924.0+ bytes

# %%
metrics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 0 to 30
# Data columns (total 9 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Year                                                   31 non-null     int64
#  1   Tobacco Price
# Index                                    31 non-null     float64
#  2   Retail Prices
# Index                                    31 non-null     float64
#  3   Tobacco Price Index Relative to Retail Price Index     31 non-null     float64
#  4   Real Households' Disposable Income                     31 non-null     float64
#  5   Affordability of Tobacco Index                         31 non-null     float64
#  6   Household Expenditure on Tobacco                       31 non-null     float64
#  7   Household Expenditure Total                            31 non-null     float64
#  8   Expenditure on Tobacco as a Percentage of Expenditure  31 non-null     float64
# dtypes: float64(8), int64(1)
# memory usage: 2.4 KB

# %%
fatalities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1749 entries, 0 to 1748
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             1749 non-null   int64
#  1   ICD10 Code       1749 non-null   object
#  2   ICD10 Diagnosis  1749 non-null   object
#  3   Diagnosis Type   1749 non-null   object
#  4   Metric           1749 non-null   object
#  5   Sex              1749 non-null   object
#  6   Value            1749 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 95.8+ KB

# %%
admissions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2078 entries, 0 to 2078
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             2078 non-null   object
#  1   ICD10 Code       2078 non-null   object
#  2   ICD10 Diagnosis  2078 non-null   object
#  3   Diagnosis Type   2078 non-null   object
#  4   Metric           2078 non-null   object
#  5   Sex              2078 non-null   object
#  6   Value            2078 non-null   object
# dtypes: object(7)
# memory usage: 129.9+ KB

# %%
# Convert 'Year' column to str
smokers['Year'] = smokers['Year'].astype(str)
prescriptions['Year'] = prescriptions['Year'].astype(str)
metrics['Year'] = metrics['Year'].astype(str)
fatalities['Year'] = fatalities['Year'].astype(str)
admissions['Year'] = admissions['Year'].astype(str)

# %%
datasets = [smokers, prescriptions, metrics, fatalities, admissions]

for df in datasets:
    df['Year'] = df['Year'].astype(str)

# %%
# Merge with other datasets
df = df.merge(prescriptions, on='Year', how='left')
df = df.merge(metrics, on='Year', how='left')
df = df.merge(fatalities, on=['Year', 'Sex'], how='left')  
df = df.merge(admissions, on=['Year', 'Sex'], how='left')

# %%
print(df.shape)
print(df.columns)
df.head()
# Out:
# (218044, 33)
# Index(['Year', 'ICD10 Code_x', 'ICD10 Diagnosis_x', 'Diagnosis Type_x',
#        'Metric_x', 'Sex', 'Value_x', 'All Pharmacotherapy Prescriptions',
#        'Nicotine Replacement Therapy (NRT) Prescriptions',
#        'Bupropion (Zyban) Prescriptions',
#        'Varenicline (Champix) Prescriptions',
#        'Net Ingredient Cost of All Pharmacotherapies',
#        'Net Ingredient Cost of Nicotine Replacement Therapies (NRT)',
#        'Net Ingredient Cost of Bupropion (Zyban)',
#        'Net Ingredient Cost of Varenicline (Champix)', 'Tobacco Price\nIndex',
#        'Retail Prices\nIndex',
#        'Tobacco Price Index Relative to Retail Price Index',
#        'Real Households' Disposable Income', 'Affordability of Tobacco Index',
#        'Household Expenditure on Tobacco', 'Household Expenditure Total',
#        'Expenditure on Tobacco as a Percentage of Expenditure', 'ICD10 Code_y',
#        'ICD10 Diagnosis_y', 'Diagnosis Type_y', 'Metric_y', 'Value_y',
#        'ICD10 Code', 'ICD10 Diagnosis', 'Diagnosis Type', 'Metric', 'Value'],
#       dtype='object')
#       Year ICD10 Code_x ICD10 Diagnosis_x Diagnosis Type_x  \
# 0  2014/15    All codes    All admissions   All admissions
# 1  2014/15    All codes    All admissions   All admissions
# 2  2014/15    All codes    All admissions   All admissions
# 3  2014/15    All codes    All admissions   All admissions
# 4  2014/15    All codes    All admissions   All admissions
#
#                Metric_x     Sex   Value_x  All Pharmacotherapy Prescriptions  \
# 0  Number of admissions  Female  11011882                               1348
# 1  Number of admissions  Female  11011882                               1348
# 2  Number of admissions  Female  11011882                               1348
# 3  Number of admissions  Female  11011882                               1348
# 4  Number of admissions  Female  11011882                               1348
#
#    Nicotine Replacement Therapy (NRT) Prescriptions  \
# 0                                               766
# 1                                               766
# 2                                               766
# 3                                               766
# 4                                               766
#
#    Bupropion (Zyban) Prescriptions  ...  ICD10 Code_y  ICD10 Diagnosis_y  \
# 0                               21  ...           NaN                NaN
# 1                               21  ...           NaN                NaN
# 2                               21  ...           NaN                NaN
# 3                               21  ...           NaN                NaN
# 4                               21  ...           NaN                NaN
#
#    Diagnosis Type_y  Metric_y  Value_y  \
# 0               NaN       NaN      NaN
# 1               NaN       NaN      NaN
# 2               NaN       NaN      NaN
# 3               NaN       NaN      NaN
# 4               NaN       NaN      NaN
#
#                                           ICD10 Code  \
# 0                                          All codes
# 1  C33-C34 & C00-C14 & C15 & C32 & C53 & C67 & C6...
# 2                                            C00-D48
# 3                                            J00-J99
# 4                                            I00-I99
#
#                                ICD10 Diagnosis  \
# 0                               All admissions
# 1  All diseases which can be caused by smoking
# 2                                  All cancers
# 3                     All respiratory diseases
# 4                     All circulatory diseases
#
#                                 Diagnosis Type                Metric     Value
# 0                               All admissions  Number of admissions  11011882
# 1  All diseases which can be caused by smoking  Number of admissions   1713330
# 2                                  All cancers  Number of admissions   1691035
# 3                     All respiratory diseases  Number of admissions    611002
# 4                     All circulatory diseases  Number of admissions    907157
#
# [5 rows x 33 columns]

# %%
# Ensure 'Year' is of the same type in all datasets (e.g., string)
for df in [smokers, prescriptions, metrics, fatalities, admissions]:
    df['Year'] = df['Year'].astype(str)

# %%
# Merge the datasets on the 'Year' column
df = pd.merge(smokers, prescriptions, on='Year', how='outer')
df = pd.merge(df, metrics, on='Year', how='outer')
df = pd.merge(df, fatalities, on='Year', how='outer')
df = pd.merge(df, admissions, on='Year', how='outer')

# %%
df
# Out:
#          Year      Method   Sex_x  16 and Over  16-24  25-34  35-49  50-59  \
# 0        1974  Unweighted  Female         46.0   44.0   51.0   52.0   50.0
# 1        1974  Unweighted    Male         51.0   47.0   55.0   55.0   53.0
# 2        1974  Unweighted  Female         41.0   41.0   47.0   49.0   48.0
# 3        1976  Unweighted  Female         42.0   42.0   45.0   48.0   48.0
# 4        1976  Unweighted    Male         46.0   43.0   48.0   50.0   50.0
# ...       ...         ...     ...          ...    ...    ...    ...    ...
# 7380  2014/15         NaN     NaN          NaN    NaN    NaN    NaN    NaN
# 7381  2014/15         NaN     NaN          NaN    NaN    NaN    NaN    NaN
# 7382  2014/15         NaN     NaN          NaN    NaN    NaN    NaN    NaN
# 7383  2014/15         NaN     NaN          NaN    NaN    NaN    NaN    NaN
# 7384     2015         NaN     NaN          NaN    NaN    NaN    NaN    NaN
#
#       60 and Over  All Pharmacotherapy Prescriptions  ...  Diagnosis Type_x  \
# 0            33.0                                NaN  ...               NaN
# 1            44.0                                NaN  ...               NaN
# 2            26.0                                NaN  ...               NaN
# 3            30.0                                NaN  ...               NaN
# 4            40.0                                NaN  ...               NaN
# ...           ...                                ...  ...               ...
# 7380          NaN                             1348.0  ...               NaN
# 7381          NaN                             1348.0  ...               NaN
# 7382          NaN                             1348.0  ...               NaN
# 7383          NaN                             1348.0  ...               NaN
# 7384          NaN                                NaN  ...               NaN
#
#       Metric_x  Sex_y  Value_x  ICD10 Code_y  \
# 0          NaN    NaN      NaN           NaN
# 1          NaN    NaN      NaN           NaN
# 2          NaN    NaN      NaN           NaN
# 3          NaN    NaN      NaN           NaN
# 4          NaN    NaN      NaN           NaN
# ...        ...    ...      ...           ...
# 7380       NaN    NaN      NaN           K05
# 7381       NaN    NaN      NaN           H25
# 7382       NaN    NaN      NaN   S72.0-S72.2
# 7383       NaN    NaN      NaN           O03
# 7384       NaN    NaN      NaN           NaN
#
#                        ICD10 Diagnosis_y  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ...                                  ...
# 7380  Periodontal Disease / Periodonitis
# 7381            Age Related Cataract 45+
# 7382                    Hip Fracture 55+
# 7383                Spontaneous Abortion
# 7384                                 NaN
#
#                                        Diagnosis Type_y             Metric_y  \
# 0                                                   NaN                  NaN
# 1                                                   NaN                  NaN
# 2                                                   NaN                  NaN
# 3                                                   NaN                  NaN
# 4                                                   NaN                  NaN
# ...                                                 ...                  ...
# 7380  Digestive diseases which can be caused caused ...  Attributable number
# 7381      Other diseases which can be caused by smoking  Attributable number
# 7382      Other diseases which can be caused by smoking  Attributable number
# 7383      Other diseases which can be caused by smoking  Attributable number
# 7384                                                NaN                  NaN
#
#          Sex  Value_y
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ...      ...      ...
# 7380  Female     1600
# 7381  Female     9000
# 7382  Female     4800
# 7383  Female      500
# 7384     NaN      NaN
#
# [7385 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 37 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Year                                                         7385 non-null   object
#  1   Method                                                       5298 non-null   object
#  2   Sex_x                                                        5298 non-null   object
#  3   16 and Over                                                  5298 non-null   float64
#  4   16-24                                                        5298 non-null   float64
#  5   25-34                                                        5298 non-null   float64
#  6   35-49                                                        5298 non-null   float64
#  7   50-59                                                        5298 non-null   float64
#  8   60 and Over                                                  5298 non-null   float64
#  9   All Pharmacotherapy Prescriptions                            2078 non-null   float64
#  10  Nicotine Replacement Therapy (NRT) Prescriptions             2078 non-null   float64
#  11  Bupropion (Zyban) Prescriptions                              2078 non-null   float64
#  12  Varenicline (Champix) Prescriptions                          2078 non-null   float64
#  13  Net Ingredient Cost of All Pharmacotherapies                 2078 non-null   float64
#  14  Net Ingredient Cost of Nicotine Replacement Therapies (NRT)  2078 non-null   float64
#  15  Net Ingredient Cost of Bupropion (Zyban)                     2078 non-null   float64
#  16  Net Ingredient Cost of Varenicline (Champix)                 2078 non-null   float64
#  17  Tobacco Price
# Index                                          5289 non-null   float64
#  18  Retail Prices
# Index                                          5289 non-null   float64
#  19  Tobacco Price Index Relative to Retail Price Index           5289 non-null   float64
#  20  Real Households' Disposable Income                           5289 non-null   float64
#  21  Affordability of Tobacco Index                               5289 non-null   float64
#  22  Household Expenditure on Tobacco                             5289 non-null   float64
#  23  Household Expenditure Total                                  5289 non-null   float64
#  24  Expenditure on Tobacco as a Percentage of Expenditure        5289 non-null   float64
#  25  ICD10 Code_x                                                 5247 non-null   object
#  26  ICD10 Diagnosis_x                                            5247 non-null   object
#  27  Diagnosis Type_x                                             5247 non-null   object
#  28  Metric_x                                                     5247 non-null   object
#  29  Sex_y                                                        5247 non-null   object
#  30  Value_x                                                      5187 non-null   float64
#  31  ICD10 Code_y                                                 2078 non-null   object
#  32  ICD10 Diagnosis_y                                            2078 non-null   object
#  33  Diagnosis Type_y                                             2078 non-null   object
#  34  Metric_y                                                     2078 non-null   object
#  35  Sex                                                          2078 non-null   object
#  36  Value_y                                                      2038 non-null   float64
# dtypes: float64(24), object(13)
# memory usage: 2.1+ MB

# %%
df.isnull().sum()
# Out:
# Year                                                              0
# Method                                                         2087
# Sex_x                                                          2087
# 16 and Over                                                    2087
# 16-24                                                          2087
# 25-34                                                          2087
# 35-49                                                          2087
# 50-59                                                          2087
# 60 and Over                                                    2087
# All Pharmacotherapy Prescriptions                              5307
# Nicotine Replacement Therapy (NRT) Prescriptions               5307
# Bupropion (Zyban) Prescriptions                                5307
# Varenicline (Champix) Prescriptions                            5307
# Net Ingredient Cost of All Pharmacotherapies                   5307
# Net Ingredient Cost of Nicotine Replacement Therapies (NRT)    5307
# Net Ingredient Cost of Bupropion (Zyban)                       5307
# Net Ingredient Cost of Varenicline (Champix)                   5307
# Tobacco Price\nIndex                                           2096
# Retail Prices\nIndex                                           2096
# Tobacco Price Index Relative to Retail Price Index             2096
# Real Households' Disposable Income                             2096
# Affordability of Tobacco Index                                 2096
# Household Expenditure on Tobacco                               2096
# Household Expenditure Total                                    2096
# Expenditure on Tobacco as a Percentage of Expenditure          2096
# ICD10 Code_x                                                   2138
# ICD10 Diagnosis_x                                              2138
# Diagnosis Type_x                                               2138
# Metric_x                                                       2138
# Sex_y                                                          2138
# Value_x                                                        2198
# ICD10 Code_y                                                   5307
# ICD10 Diagnosis_y                                              5307
# Diagnosis Type_y                                               5307
# Metric_y                                                       5307
# Sex                                                            5307
# Value_y                                                        5347
# dtype: int64

# %%
# Load cleaned data
smokers = pd.read_csv("smokers_cleaned.csv")
prescriptions = pd.read_csv("prescriptions_cleaned.csv")
metrics = pd.read_csv("metrics_cleaned.csv")
fatalities = pd.read_csv("fatalities_cleaned.csv")
admissions = pd.read_csv("admissions_cleaned.csv")

# %%
# Ensure 'Year' is of the same type in all datasets (e.g., string)
for df in [smokers, prescriptions, metrics, fatalities, admissions]:
    df['Year'] = df['Year'].astype(str)

# %%
# Merge smokers and prescriptions on 'Year'
df = pd.merge(smokers, prescriptions, on='Year', how='inner')

# Merge with metrics
df = pd.merge(df, metrics, on='Year', how='inner')

# %%
# Merge wide-format datasets
df = smokers.merge(prescriptions, on='Year', how='inner') \
            .merge(metrics, on='Year', how='inner')

# %%
# Convert 'Value' column to numeric for both
fatalities['Value'] = pd.to_numeric(fatalities['Value'], errors='coerce')
admissions['Value'] = pd.to_numeric(admissions['Value'], errors='coerce')

# %%
# Show result
print("Merged dataset shape:", df.shape)
print(df.head())
# Out:
# Merged dataset shape: (0, 25)
# Empty DataFrame
# Columns: [Year, Method, Sex, 16 and Over, 16-24, 25-34, 35-49, 50-59, 60 and Over, All Pharmacotherapy Prescriptions, Nicotine Replacement Therapy (NRT) Prescriptions, Bupropion (Zyban) Prescriptions, Varenicline (Champix) Prescriptions, Net Ingredient Cost of All Pharmacotherapies, Net Ingredient Cost of Nicotine Replacement Therapies (NRT), Net Ingredient Cost of Bupropion (Zyban), Net Ingredient Cost of Varenicline (Champix), Tobacco Price
# Index, Retail Prices
# Index, Tobacco Price Index Relative to Retail Price Index, Real Households' Disposable Income, Affordability of Tobacco Index, Household Expenditure on Tobacco, Household Expenditure Total, Expenditure on Tobacco as a Percentage of Expenditure]
# Index: []
#
# [0 rows x 25 columns]

# %%
# Ensure 'Year' is of the same type in all datasets (e.g., string)
for df in [smokers, prescriptions, metrics, fatalities, admissions]:
    df['Year'] = df['Year'].astype(str)

# %%
# Merge on 'Year' only (since not all datasets have 'Sex')
df = smokers.merge(prescriptions, on="Year", how="inner") \
            .merge(metrics, on="Year", how="inner") \
            .merge(fatalities, on="Year", how="inner") \
            .merge(admissions, on="Year", how="inner")

# %%
# Check the merged DataFrame
print("Merged DataFrame shape:", df.shape)
df.head()
# Out:
# Merged DataFrame shape: (0, 37)
# Empty DataFrame
# Columns: [Year, Method, Sex_x, 16 and Over, 16-24, 25-34, 35-49, 50-59, 60 and Over, All Pharmacotherapy Prescriptions, Nicotine Replacement Therapy (NRT) Prescriptions, Bupropion (Zyban) Prescriptions, Varenicline (Champix) Prescriptions, Net Ingredient Cost of All Pharmacotherapies, Net Ingredient Cost of Nicotine Replacement Therapies (NRT), Net Ingredient Cost of Bupropion (Zyban), Net Ingredient Cost of Varenicline (Champix), Tobacco Price
# Index, Retail Prices
# Index, Tobacco Price Index Relative to Retail Price Index, Real Households' Disposable Income, Affordability of Tobacco Index, Household Expenditure on Tobacco, Household Expenditure Total, Expenditure on Tobacco as a Percentage of Expenditure, ICD10 Code_x, ICD10 Diagnosis_x, Diagnosis Type_x, Metric_x, Sex_y, Value_x, ICD10 Code_y, ICD10 Diagnosis_y, Diagnosis Type_y, Metric_y, Sex, Value_y]
# Index: []
#
# [0 rows x 37 columns]
